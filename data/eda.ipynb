# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train_new.csv')
df.shape
# Out:
# (178258, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178258 entries, 0 to 178257
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                178258 non-null  int64
#  1   gender            178258 non-null  object
#  2   SeniorCitizen     178258 non-null  int64
#  3   Partner           178258 non-null  object
#  4   Dependents        178258 non-null  object
#  5   tenure            178258 non-null  int64
#  6   PhoneService      178258 non-null  object
#  7   MultipleLines     178258 non-null  object
#  8   InternetService   178258 non-null  object
#  9   OnlineSecurity    178258 non-null  object
#  10  OnlineBackup      178258 non-null  object
#  11  DeviceProtection  178258 non-null  object
#  12  TechSupport       178258 non-null  object
#  13  StreamingTV       178258 non-null  object
#  14  StreamingMovies   178258 non-null  object
#  15  Contract          178258 non-null  object
#  16  PaperlessBilling  178258 non-null  object
#  17  PaymentMethod     178258 non-null  object
#  18  MonthlyCharges    178258 non-null  float64
#  19  TotalCharges      178258 non-null  float64
#  20  Churn             178258 non-null  object
# dtypes: float64(2), int64(3), object(16)
# memory usage: 28.6+ MB

# %%
df.Churn.value_counts(normalize=True)
# Out:
# Churn
# No     0.77417
# Yes    0.22583
# Name: proportion, dtype: float64

# %%
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['id', 'gender', 'seniorcitizen', 'partner', 'dependents', 'tenure',
#        'phoneservice', 'multiplelines', 'internetservice', 'onlinesecurity',
#        'onlinebackup', 'deviceprotection', 'techsupport', 'streamingtv',
#        'streamingmovies', 'contract', 'paperlessbilling', 'paymentmethod',
#        'monthlycharges', 'totalcharges', 'churn'],
#       dtype='object')

# %%
df.drop('id',axis=1,inplace=True)

# %%
df.sample()
# Out:
#        gender  seniorcitizen partner dependents  tenure phoneservice  \
# 117752   Male              0     Yes         No      53          Yes
#
#        multiplelines internetservice onlinesecurity onlinebackup  \
# 117752           Yes     Fiber optic             No          Yes
#
#        deviceprotection techsupport streamingtv streamingmovies  \
# 117752               No          No         Yes             Yes
#
#               contract paperlessbilling     paymentmethod  monthlycharges  \
# 117752  Month-to-month              Yes  Electronic check           100.2
#
#         totalcharges churn
# 117752        5200.8    No

# %%
df.isna().sum()
# Out:
# gender              0
# seniorcitizen       0
# partner             0
# dependents          0
# tenure              0
# phoneservice        0
# multiplelines       0
# internetservice     0
# onlinesecurity      0
# onlinebackup        0
# deviceprotection    0
# techsupport         0
# streamingtv         0
# streamingmovies     0
# contract            0
# paperlessbilling    0
# paymentmethod       0
# monthlycharges      0
# totalcharges        0
# churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
